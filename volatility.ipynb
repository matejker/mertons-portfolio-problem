# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from libs.clients import AlphaVantage

# %%
client = AlphaVantage()
spx500 = await client.get_time_series_daily("SPY", csv_format=True)

# %%
plt.figure(figsize=(15, 7))
plt.plot(spx500["timestamp"][::-1], pd.to_numeric(spx500['close'][::-1]))
plt.xticks([t for k, t in enumerate(spx500["timestamp"][::-1]) if k % 10 == 1])
plt.show()

# %%
pd.to_numeric(spx500['close']).std()
# Out:
# 68.95773506839996

# %%
spx500
# Out:
# Empty DataFrame
# Columns: [{
#     "Error Message": "Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_DAILY."
# }]
# Index: []
